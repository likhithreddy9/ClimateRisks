# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Load dataset
df = pd.read_csv('C:/Users/vikra/OneDrive/Documents/ocean-acidification-data.csv')

#Display the first few rows
print(df.head())
# Out:
#      year  Gas(TWh,direct energy)  Oil(TWh,direct energy)  \
# 0  1950.0                  2092.0                  5444.0
# 1  1951.0                  2200.0                  6000.0
# 2  1952.0                  2400.0                  6500.0
# 3  1953.0                  2600.0                  7000.0
# 4  1954.0                  2700.0                  7500.0
#
#    Cole(TWh,direct energy)  Nuclear (% direct primary energy)  \
# 0                  12603.0                                0.5
# 1                  12800.0                                0.5
# 2                  13000.0                                0.5
# 3                  13200.0                                0.5
# 4                  13500.0                                0.5
#
#    Renewables (% direct primary energy)  \
# 0                                   1.0
# 1                                   1.0
# 2                                   1.0
# 3                                   1.0
# 4                                   1.0
#
#    Fossil fuels (% direct primary energy)  \
# 0                                    98.5
# 1                                    98.5
# 2                                    98.5
# 3                                    98.5
# 4                                    98.5
#
#    Annual_GHG_emision_(in_billion_tons)  Global_average_temperature  \
# 0                                 16.52                   -0.226622
# 1                                 17.18                   -0.061154
# 2                                 17.51                    0.015355
# 3                                 17.92                    0.077631
# 4                                 18.35                   -0.116750
#
#    Global_warming_contribution_from_fossil_fuels  \
# 0                                       0.151223
# 1                                       0.155539
# 2                                       0.160021
# 3                                       0.164643
# 4                                       0.169367
#
#    Co2_emissions_from_fossil_fuels(in billion tons)  \
# 0                                      5.929342e+09
# 1                                      6.381406e+09
# 2                                      6.467437e+09
# 3                                      6.650862e+09
# 4                                      6.789497e+09
#
#    number_death_from_natural_disasters  Ocean_acidification(in_PH)
# 0                                 6845                        8.15
# 1                                18227                        8.15
# 2                                 6886                        8.15
# 3                                12516                        8.15
# 4                                41847                        8.15

# %%
#basic information
print(df.info())
print(df.describe())
print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 75 entries, 0 to 74
# Data columns (total 13 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   year                                              74 non-null     float64
#  1   Gas(TWh,direct energy)                            74 non-null     float64
#  2   Oil(TWh,direct energy)                            74 non-null     float64
#  3   Cole(TWh,direct energy)                           74 non-null     float64
#  4   Nuclear (% direct primary energy)                 74 non-null     float64
#  5   Renewables (% direct primary energy)              74 non-null     float64
#  6   Fossil fuels (% direct primary energy)            74 non-null     float64
#  7   Annual_GHG_emision_(in_billion_tons)              73 non-null     float64
#  8   Global_average_temperature                        74 non-null     float64
#  9   Global_warming_contribution_from_fossil_fuels     73 non-null     float64
#  10  Co2_emissions_from_fossil_fuels(in billion tons)  73 non-null     float64
#  11  number_death_from_natural_disasters               75 non-null     int64
#  12  Ocean_acidification(in_PH)                        73 non-null     float64
# dtypes: float64(12), int64(1)
# memory usage: 7.7 KB
# None
#               year  Gas(TWh,direct energy)  Oil(TWh,direct energy)  \
# count    74.000000               74.000000               74.000000
# mean   1986.500000            18380.148189            33744.271432
# std      21.505813            11633.744031            14717.380210
# min    1950.000000             2092.000000             5444.000000
# 25%    1968.250000             8241.619275            22995.007250
# 50%    1986.500000            16851.500000            36666.447000
# 75%    2004.750000            27262.804750            46516.334500
# max    2023.000000            40239.016000            54564.000000
#
#        Cole(TWh,direct energy)  Nuclear (% direct primary energy)  \
# count                74.000000                          74.000000
# mean              26125.361892                           1.428199
# std               10910.584168                           0.879313
# min               12603.000000                           0.061586
# 25%               16481.323250                           0.500000
# 50%               24746.152000                           1.805756
# 75%               35565.533500                           2.223695
# max               45564.930000                           2.623547
#
#        Renewables (% direct primary energy)  \
# count                             74.000000
# mean                               2.887757
# std                                1.309290
# min                                1.000000
# 25%                                2.284048
# 50%                                2.733285
# 75%                                3.027454
# max                                6.723903
#
#        Fossil fuels (% direct primary energy)  \
# count                               74.000000
# mean                                95.684058
# std                                  1.928957
# min                                 91.489980
# 25%                                 94.433937
# 50%                                 95.212365
# 75%                                 97.453785
# max                                 98.500000
#
#        Annual_GHG_emision_(in_billion_tons)  Global_average_temperature  \
# count                             73.000000                   74.000000
# mean                              35.421096                    0.246311
# std                               11.258415                    0.355629
# min                               16.520000                   -0.305862
# 25%                               25.410000                   -0.045206
# 50%                               35.560000                    0.187661
# 75%                               44.330000                    0.543994
# max                               53.850000                    1.100313
#
#        Global_warming_contribution_from_fossil_fuels  \
# count                                      73.000000
# mean                                        0.514881
# std                                         0.269636
# min                                         0.151223
# 25%                                         0.270426
# 50%                                         0.479984
# 75%                                         0.719875
# max                                         1.058829
#
#        Co2_emissions_from_fossil_fuels(in billion tons)  \
# count                                      7.300000e+01
# mean                                       2.120585e+10
# std                                        9.570216e+09
# min                                        5.929342e+09
# 25%                                        1.290434e+10
# 50%                                        2.060752e+10
# 75%                                        2.862019e+10
# max                                        3.714979e+10
#
#        number_death_from_natural_disasters  Ocean_acidification(in_PH)
# count                            75.000000                   73.000000
# mean                          99570.253333                    8.111480
# std                          178287.264999                    0.030738
# min                            1520.000000                    8.046250
# 25%                           11794.000000                    8.087089
# 50%                           21847.000000                    8.112000
# 75%                           81308.500000                    8.142000
# max                          997729.000000                    8.150000
# year                                                1
# Gas(TWh,direct energy)                              1
# Oil(TWh,direct energy)                              1
# Cole(TWh,direct energy)                             1
# Nuclear (% direct primary energy)                   1
# Renewables (% direct primary energy)                1
# Fossil fuels (% direct primary energy)              1
# Annual_GHG_emision_(in_billion_tons)                2
# Global_average_temperature                          1
# Global_warming_contribution_from_fossil_fuels       2
# Co2_emissions_from_fossil_fuels(in billion tons)    2
# number_death_from_natural_disasters                 0
# Ocean_acidification(in_PH)                          2
# dtype: int64
